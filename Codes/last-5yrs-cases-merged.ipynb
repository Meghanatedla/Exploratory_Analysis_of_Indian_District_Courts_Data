# %% [markdown]
# ***Trend of disposition for the last five years***

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/court-data/judges_clean/judges_clean.csv
# /kaggle/input/court-data/acts_sections/acts_sections.csv
# /kaggle/input/court-data/cases/cases/cases_2015.csv
# /kaggle/input/court-data/cases/cases/cases_2012.csv
# /kaggle/input/court-data/cases/cases/cases_2018.csv
# /kaggle/input/court-data/cases/cases/cases_2013.csv
# /kaggle/input/court-data/cases/cases/cases_2017.csv
# /kaggle/input/court-data/cases/cases/cases_2010.csv
# /kaggle/input/court-data/cases/cases/cases_2014.csv
# /kaggle/input/court-data/cases/cases/cases_2016.csv
# /kaggle/input/court-data/cases/cases/cases_2011.csv
# /kaggle/input/court-data/keys/keys/type_name_key.csv
# /kaggle/input/court-data/keys/keys/cases_district_key.csv
# /kaggle/input/court-data/keys/keys/act_key.csv
# /kaggle/input/court-data/keys/keys/disp_name_key.csv
# /kaggle/input/court-data/keys/keys/purpose_name_key.csv
# /kaggle/input/court-data/keys/keys/cases_state_key.csv
# /kaggle/input/court-data/keys/keys/section_key.csv
# ...

# %%
cases_2014 = pd.read_csv("/kaggle/input/court-data/cases/cases/cases_2014.csv")
cases_2014
# Out:
#                       ddl_case_id  year  state_code  dist_code  court_no  \
# 0        01-01-01-201908000022014  2014           1          1         1
# 1        01-01-01-201908000032014  2014           1          1         1
# 2        01-01-01-201908000052014  2014           1          1         1
# 3        01-01-01-201908000062014  2014           1          1         1
# 4        01-01-01-201908000072014  2014           1          1         1
# ...                           ...   ...         ...        ...       ...
# 8874611  33-02-02-219600000252014  2014          33          2         2
# 8874612  33-02-02-224400000312014  2014          33          2         2
# 8874613  33-02-03-202100000392014  2014          33          2         3
# 8874614  33-02-03-202100000452014  2014          33          2         3
# 8874615  33-02-03-202100000592014  2014          33          2         3
#
#                      cino             judge_position female_defendant  \
# ...

# %%
list(cases_2014.columns)
# Out:
# ['ddl_case_id',
#  'year',
#  'state_code',
#  'dist_code',
#  'court_no',
#  'cino',
#  'judge_position',
#  'female_defendant',
#  'female_petitioner',
#  'female_adv_def',
#  'female_adv_pet',
#  'type_name',
#  'purpose_name',
#  'disp_name',
#  'date_of_filing',
#  'date_of_decision',
#  'date_first_list',
#  'date_last_list',
#  'date_next_list']

# %%
cols = ['dist_code', 'court_no', 'cino', 'female_defendant', 'female_petitioner', 'female_adv_def', 'female_adv_pet', 'type_name', 'purpose_name', 'date_first_list', 'date_last_list', 'date_next_list']

# %%
cases_2014.drop(columns=cols, inplace=True)
cases_2014
# Out:
#                       ddl_case_id  year  state_code  \
# 0        01-01-01-201908000022014  2014           1
# 1        01-01-01-201908000032014  2014           1
# 2        01-01-01-201908000052014  2014           1
# 3        01-01-01-201908000062014  2014           1
# 4        01-01-01-201908000072014  2014           1
# ...                           ...   ...         ...
# 8874611  33-02-02-219600000252014  2014          33
# 8874612  33-02-02-224400000312014  2014          33
# 8874613  33-02-03-202100000392014  2014          33
# 8874614  33-02-03-202100000452014  2014          33
# 8874615  33-02-03-202100000592014  2014          33
#
#                     judge_position  disp_name date_of_filing date_of_decision
# 0        chief judicial magistrate         25     2014-01-03       2014-10-28
# 1        chief judicial magistrate         25     2014-01-01       2015-08-10
# 2        chief judicial magistrate         25     2014-01-02       2014-06-10
# ...

# %%
cases_2015 = pd.read_csv("/kaggle/input/court-data/cases/cases/cases_2015.csv")
cases_2015
# Out:
#                        ddl_case_id  year  state_code  dist_code  court_no  \
# 0         01-01-01-201908000012015  2015           1          1         1
# 1         01-01-01-201908000022015  2015           1          1         1
# 2         01-01-01-201908000032015  2015           1          1         1
# 3         01-01-01-201908000042015  2015           1          1         1
# 4         01-01-01-201908000052015  2015           1          1         1
# ...                            ...   ...         ...        ...       ...
# 10475871  33-02-03-217800000792015  2015          33          2         3
# 10475872  33-02-03-218300000082015  2015          33          2         3
# 10475873  33-02-03-218300000102015  2015          33          2         3
# 10475874  33-02-03-220700000072015  2015          33          2         3
# 10475875  33-02-03-224100000822015  2015          33          2         3
#
#                       cino             judge_position female_defendant  \
# ...

# %%
cases_2015.drop(columns=cols, inplace=True)
cases_2015
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201908000012015  2015           1
# 1         01-01-01-201908000022015  2015           1
# 2         01-01-01-201908000032015  2015           1
# 3         01-01-01-201908000042015  2015           1
# 4         01-01-01-201908000052015  2015           1
# ...                            ...   ...         ...
# 10475871  33-02-03-217800000792015  2015          33
# 10475872  33-02-03-218300000082015  2015          33
# 10475873  33-02-03-218300000102015  2015          33
# 10475874  33-02-03-220700000072015  2015          33
# 10475875  33-02-03-224100000822015  2015          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         25     2015-01-01       2015-02-25
# 1         chief judicial magistrate         30     2015-01-02       2016-12-01
# 2         chief judicial magistrate         32     2015-01-02       2015-02-25
# ...

# %%
cases_2016 = pd.read_csv("/kaggle/input/court-data/cases/cases/cases_2016.csv")
cases_2016
# Out:
#                        ddl_case_id  year  state_code  dist_code  court_no  \
# 0         01-01-01-201900000012016  2016           1          1         1
# 1         01-01-01-201900000022016  2016           1          1         1
# 2         01-01-01-201900000032016  2016           1          1         1
# 3         01-01-01-201900000042016  2016           1          1         1
# 4         01-01-01-201900000052016  2016           1          1         1
# ...                            ...   ...         ...        ...       ...
# 11349255  33-02-03-220700000112016  2016          33          2         3
# 11349256  33-02-03-220700000152016  2016          33          2         3
# 11349257  33-02-03-221800000352016  2016          33          2         3
# 11349258  33-02-03-224000000112016  2016          33          2         3
# 11349259  33-02-03-224300000032016  2016          33          2         3
#
#                       cino             judge_position female_defendant  \
# ...

# %%
cases_2016.drop(columns=cols, inplace=True)
cases_2016
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201900000012016  2016           1
# 1         01-01-01-201900000022016  2016           1
# 2         01-01-01-201900000032016  2016           1
# 3         01-01-01-201900000042016  2016           1
# 4         01-01-01-201900000052016  2016           1
# ...                            ...   ...         ...
# 11349255  33-02-03-220700000112016  2016          33
# 11349256  33-02-03-220700000152016  2016          33
# 11349257  33-02-03-221800000352016  2016          33
# 11349258  33-02-03-224000000112016  2016          33
# 11349259  33-02-03-224300000032016  2016          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         26     2016-01-02       2016-02-16
# 1         chief judicial magistrate         26     2016-01-02       2016-02-16
# 2         chief judicial magistrate         43     2016-01-02       2016-02-13
# ...

# %%
cases_2017 = pd.read_csv("/kaggle/input/court-data/cases/cases/cases_2017.csv")
cases_2017
# Out:
#                        ddl_case_id  year  state_code  dist_code  court_no  \
# 0         01-01-01-201900000012017  2017           1          1         1
# 1         01-01-01-201900000022017  2017           1          1         1
# 2         01-01-01-201900000032017  2017           1          1         1
# 3         01-01-01-201900000042017  2017           1          1         1
# 4         01-01-01-201900000052017  2017           1          1         1
# ...                            ...   ...         ...        ...       ...
# 13065508  33-02-03-224000000122017  2017          33          2         3
# 13065509  33-02-03-224000000132018  2017          33          2         3
# 13065510  33-02-03-224100000122017  2017          33          2         3
# 13065511  33-02-03-224600000012018  2017          33          2         3
# 13065512  33-02-03-224600000092017  2017          33          2         3
#
#                       cino             judge_position female_defendant  \
# ...

# %%
cases_2017.drop(columns=cols, inplace=True)
cases_2017
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201900000012017  2017           1
# 1         01-01-01-201900000022017  2017           1
# 2         01-01-01-201900000032017  2017           1
# 3         01-01-01-201900000042017  2017           1
# 4         01-01-01-201900000052017  2017           1
# ...                            ...   ...         ...
# 13065508  33-02-03-224000000122017  2017          33
# 13065509  33-02-03-224000000132018  2017          33
# 13065510  33-02-03-224100000122017  2017          33
# 13065511  33-02-03-224600000012018  2017          33
# 13065512  33-02-03-224600000092017  2017          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         26     2017-01-02       2017-03-06
# 1         chief judicial magistrate         26     2017-01-04       2017-02-27
# 2         chief judicial magistrate         31     2017-01-04       2017-01-21
# ...

# %%
cases_2018 = pd.read_csv("/kaggle/input/court-data/cases/cases/cases_2018.csv")
cases_2018
# Out:
#                        ddl_case_id  year  state_code  dist_code  court_no  \
# 0         01-01-01-201900000012018  2018           1          1         1
# 1         01-01-01-201900000022018  2018           1          1         1
# 2         01-01-01-201900000032018  2018           1          1         1
# 3         01-01-01-201900000042018  2018           1          1         1
# 4         01-01-01-201900000052018  2018           1          1         1
# ...                            ...   ...         ...        ...       ...
# 13724294  33-02-03-224600000062018  2018          33          2         3
# 13724295  33-02-03-224600000072018  2018          33          2         3
# 13724296  33-02-03-224600000082018  2018          33          2         3
# 13724297  33-02-03-224600000092018  2018          33          2         3
# 13724298  33-02-03-224600000102018  2018          33          2         3
#
#                       cino             judge_position female_defendant  \
# ...

# %%
cases_2018.drop(columns=cols, inplace=True)
cases_2018
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201900000012018  2018           1
# 1         01-01-01-201900000022018  2018           1
# 2         01-01-01-201900000032018  2018           1
# 3         01-01-01-201900000042018  2018           1
# 4         01-01-01-201900000052018  2018           1
# ...                            ...   ...         ...
# 13724294  33-02-03-224600000062018  2018          33
# 13724295  33-02-03-224600000072018  2018          33
# 13724296  33-02-03-224600000082018  2018          33
# 13724297  33-02-03-224600000092018  2018          33
# 13724298  33-02-03-224600000102018  2018          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         33     2018-01-01       2018-02-07
# 1         chief judicial magistrate         52     2018-01-01       2018-02-01
# 2         chief judicial magistrate         52     2018-01-01       2018-02-01
# ...

# %%
#Merging Data of Last five years

# %%
cases_last_5yrs = cases_2014.append(cases_2015, ignore_index=True)
cases_last_5yrs
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201908000022014  2014           1
# 1         01-01-01-201908000032014  2014           1
# 2         01-01-01-201908000052014  2014           1
# 3         01-01-01-201908000062014  2014           1
# 4         01-01-01-201908000072014  2014           1
# ...                            ...   ...         ...
# 19350487  33-02-03-217800000792015  2015          33
# 19350488  33-02-03-218300000082015  2015          33
# 19350489  33-02-03-218300000102015  2015          33
# 19350490  33-02-03-220700000072015  2015          33
# 19350491  33-02-03-224100000822015  2015          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         25     2014-01-03       2014-10-28
# 1         chief judicial magistrate         25     2014-01-01       2015-08-10
# 2         chief judicial magistrate         25     2014-01-02       2014-06-10
# ...

# %%
# deleting 'cases_2015' dataFrame from memory

# %%
import warnings
warnings.simplefilter('ignore')
import gc
import subprocess

# %%
del cases_2014
gc.collect()
# Out:
# 112

# %%
del cases_2015
gc.collect()
# Out:
# 21

# %%
cases_last_5yrs = cases_last_5yrs.append(cases_2016, ignore_index=True)
cases_last_5yrs
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201908000022014  2014           1
# 1         01-01-01-201908000032014  2014           1
# 2         01-01-01-201908000052014  2014           1
# 3         01-01-01-201908000062014  2014           1
# 4         01-01-01-201908000072014  2014           1
# ...                            ...   ...         ...
# 30699747  33-02-03-220700000112016  2016          33
# 30699748  33-02-03-220700000152016  2016          33
# 30699749  33-02-03-221800000352016  2016          33
# 30699750  33-02-03-224000000112016  2016          33
# 30699751  33-02-03-224300000032016  2016          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         25     2014-01-03       2014-10-28
# 1         chief judicial magistrate         25     2014-01-01       2015-08-10
# 2         chief judicial magistrate         25     2014-01-02       2014-06-10
# ...

# %%
del cases_2016
gc.collect()
# Out:
# 42

# %%
cases_last_5yrs = cases_last_5yrs.append(cases_2017, ignore_index=True)
cases_last_5yrs
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201908000022014  2014           1
# 1         01-01-01-201908000032014  2014           1
# 2         01-01-01-201908000052014  2014           1
# 3         01-01-01-201908000062014  2014           1
# 4         01-01-01-201908000072014  2014           1
# ...                            ...   ...         ...
# 43765260  33-02-03-224000000122017  2017          33
# 43765261  33-02-03-224000000132018  2017          33
# 43765262  33-02-03-224100000122017  2017          33
# 43765263  33-02-03-224600000012018  2017          33
# 43765264  33-02-03-224600000092017  2017          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         25     2014-01-03       2014-10-28
# 1         chief judicial magistrate         25     2014-01-01       2015-08-10
# 2         chief judicial magistrate         25     2014-01-02       2014-06-10
# ...

# %%
del cases_2017
gc.collect()
# Out:
# 42

# %%
cases_last_5yrs = cases_last_5yrs.append(cases_2018, ignore_index=True)
cases_last_5yrs
# Out:
#                        ddl_case_id  year  state_code  \
# 0         01-01-01-201908000022014  2014           1
# 1         01-01-01-201908000032014  2014           1
# 2         01-01-01-201908000052014  2014           1
# 3         01-01-01-201908000062014  2014           1
# 4         01-01-01-201908000072014  2014           1
# ...                            ...   ...         ...
# 57489559  33-02-03-224600000062018  2018          33
# 57489560  33-02-03-224600000072018  2018          33
# 57489561  33-02-03-224600000082018  2018          33
# 57489562  33-02-03-224600000092018  2018          33
# 57489563  33-02-03-224600000102018  2018          33
#
#                      judge_position  disp_name date_of_filing date_of_decision
# 0         chief judicial magistrate         25     2014-01-03       2014-10-28
# 1         chief judicial magistrate         25     2014-01-01       2015-08-10
# 2         chief judicial magistrate         25     2014-01-02       2014-06-10
# ...

# %%
del cases_2018
gc.collect()
# Out:
# 42

# %%
cases_last_5yrs.to_csv("/kaggle/working/cases_last_5yrs.csv")

# %%
# disp_name_key = pd.read_csv("/kaggle/input/court-data/keys/keys/disp_name_key.csv")
# disp_name_key.head(10)

# %%
# disp_name_key.drop(columns=['year', 'count'], inplace=True)
# disp_name_key.head(10)

# %%
# cases_last_5yrs = pd.merge(cases_last_5yrs, disp_name_key, how='left', on='disp_name')
# cases_last_5yrs.head(10)
